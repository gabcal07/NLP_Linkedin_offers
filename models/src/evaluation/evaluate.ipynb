# %% [markdown]
# ### Imports

# %%
import pandas as pd
import os
import sys

# %% [markdown]
# ### Set project root

# %%
project_root = os.path.abspath(
    os.path.join(os.getcwd(), '../../../')
)
if project_root not in sys.path:
    sys.path.append(project_root)

from models.src.evaluation.custom_evaluate import evaluate_dataset

# %% [markdown]
# ### Get dataframes

# %%
bart_dataset_path = os.path.join(project_root, 'models', 'src', 'generation', 'transformers', 'golden_dataset_facebook_bart-base.csv')
t5_dataset_path = os.path.join(project_root, 'models', 'src', 'generation', 'transformers', 'golden_dataset_t5-small.csv')
gpt2_dataset_path = os.path.join(project_root, 'models', 'src', 'generation', 'transformers', 'golden_dataset_gpt2.csv')
bart_df = pd.read_csv(bart_dataset_path)
gpt2_df = pd.read_csv(gpt2_dataset_path)
t5_df = pd.read_csv(t5_dataset_path)
small_gpt2_df = pd.read_csv(os.path.join(project_root, 'models', 'src', 'generation', 'transformers', 'small_golden_dataset_gpt2.csv'))

# rename the column prediction to predictions
bart_df.rename(columns={'prediction': 'predictions'}, inplace=True)
gpt2_df.rename(columns={'prediction': 'predictions'}, inplace=True)
t5_df.rename(columns={'prediction': 'predictions'}, inplace=True)
gpt2_df.rename(columns={'input': 'inputs'}, inplace=True)
small_gpt2_df.rename(columns={'input': 'inputs'}, inplace=True)
small_gpt2_df.rename(columns={'prediction': 'predictions'}, inplace=True)

# Create a column input that takes the first 50 words of the ground_truth
bart_df['inputs'] = bart_df['ground_truth'].apply(lambda x: ' '.join(x.split()[:50]))
# gpt2_df['inputs'] = gpt2_df['ground_truth'].apply(lambda x: ' '.join(x.split()[:50]))
t5_df['inputs'] = t5_df['ground_truth'].apply(lambda x: ' '.join(x.split()[:50]))
display(bart_df.head())
display(gpt2_df.head())
display(t5_df.head())
display(small_gpt2_df.head())
# Out:
#                                          predictions  \
# 0  As a Publix Pharmacy Associate, you ll see how...
# 1  Job Title Release Manager CLT Duration 12 18 m...
# 2  About This Role Wells Fargo is seeking a Senio...
# 3  We ve made a lot of progress since opening the...
# 4  At Whole Foods Market, we re committed to prov...
#
#                                         ground_truth  \
# 0  As a Publix Pharmacy Associate, you ll see how...
# 1  Job Title Release Manager CLT Duration 12 18 m...
# 2  About This Role Wells Fargo is seeking a Senio...
# 3  We ve made a lot of progress since opening the...
# 4  At Whole Foods Market, we re committed to prov...
#
#                                               inputs
# 0  As a Publix Pharmacy Associate, you ll see how...
# 1  Job Title Release Manager CLT Duration 12 18 m...
# 2  About This Role Wells Fargo is seeking a Senio...
# 3  We ve made a lot of progress since opening the...
# 4  At Whole Foods Market, we re committed to prov...
#                                          predictions  \
# 0  As a Publix Pharmacy Associate, you ll see how...
# 1  Job Title Release Manager CLT Duration 12 18 m...
# 2  About This Role Wells Fargo is seeking a Senio...
# 3  We ve made a lot of progress since opening the...
# 4  At Whole Foods Market, we re committed to prov...
#
#                                         ground_truth  \
# 0  As a Publix Pharmacy Associate, you ll see how...
# 1  Job Title Release Manager CLT Duration 12 18 m...
# 2  About This Role Wells Fargo is seeking a Senio...
# 3  We ve made a lot of progress since opening the...
# 4  At Whole Foods Market, we re committed to prov...
#
#                                               inputs
# 0  As a Publix Pharmacy Associate, you ll see how...
# 1  Job Title Release Manager CLT Duration 12 18 m...
# 2  About This Role Wells Fargo is seeking a Senio...
# 3  We ve made a lot of progress since opening the...
# 4  At Whole Foods Market, we re committed to prov...
#                                          predictions  \
# 0  As a Publix Pharmacy Associate, you ll see how...
# 1  Job Title Release Manager CLT Duration 12 18 m...
# 2  About This Role Wells Fargo is seeking a Senio...
# 3  We ve made a lot of progress since opening the...
# 4  At Whole Foods Market, we re committed to prov...
#
#                                         ground_truth  \
# 0  As a Publix Pharmacy Associate, you ll see how...
# 1  Job Title Release Manager CLT Duration 12 18 m...
# 2  About This Role Wells Fargo is seeking a Senio...
# 3  We ve made a lot of progress since opening the...
# 4  At Whole Foods Market, we re committed to prov...
#
#                                               inputs
# 0  As a Publix Pharmacy Associate, you ll see how...
# 1  Job Title Release Manager CLT Duration 12 18 m...
# 2  About This Role Wells Fargo is seeking a Senio...
# 3  We ve made a lot of progress since opening the...
# 4  At Whole Foods Market, we re committed to prov...
#                                          predictions  \
# 0  As a Publix Pharmacy Associate, you ll see how...
# 1  Job Title Release Manager CLT Duration 12 18 m...
# 2  About This Role Wells Fargo is seeking a Senio...
# 3  We ve made a lot of progress since opening the...
# 4  At Whole Foods Market, we re committed to prov...
#
#                                         ground_truth  \
# 0  As a Publix Pharmacy Associate, you ll see how...
# 1  Job Title Release Manager CLT Duration 12 18 m...
# 2  About This Role Wells Fargo is seeking a Senio...
# 3  We ve made a lot of progress since opening the...
# 4  At Whole Foods Market, we re committed to prov...
#
#                                               inputs
# 0  As a Publix Pharmacy Associate, you ll see how...
# 1  Job Title Release Manager CLT Duration 12 18 m...
# 2  About This Role Wells Fargo is seeking a Senio...
# 3  We ve made a lot of progress since opening the...
# 4  At Whole Foods Market, we re committed to prov...

# %% [markdown]
# ### Sample 50 random rows from each dataframe

# %%
small_t5_df = t5_df.sample(n=10, random_state=42)
small_bart_df = bart_df.sample(n=10, random_state=42)
# small_gpt2_df = gpt2_df.sample(n=10, random_state=42)
display(small_t5_df.head())
display(small_bart_df.head())
display(small_gpt2_df.head())
# Out:
#                                             predictions  \
# 1501  RK K is hiring Transportation Engineers throug...
# 2586  Only Citizens GCs Preference for candidates lo...
# 2653  Ekeo Group is looking for a Senior Financial A...
# 1055  At Belk, we have a vision to reimagine the dep...
# 705   Food Safety QA Technical Manager Princeton, N....
#
#                                            ground_truth  \
# 1501  RK K is hiring Transportation Engineers throug...
# 2586  Only Citizens GCs Preference for candidates lo...
# 2653  Ekeo Group is looking for a Senior Financial A...
# 1055  At Belk, we have a vision to reimagine the dep...
# 705   Food Safety QA Technical Manager Princeton, N....
#
#                                                  inputs
# 1501  RK K is hiring Transportation Engineers throug...
# 2586  Only Citizens GCs Preference for candidates lo...
# 2653  Ekeo Group is looking for a Senior Financial A...
# 1055  At Belk, we have a vision to reimagine the dep...
# 705   Food Safety QA Technical Manager Princeton, N....
#                                             predictions  \
# 1501  RK K is hiring Transportation Engineers throug...
# 2586  Only Citizens GCs Preference for candidates lo...
# 2653  Ekeo Group is looking for a Senior Financial A...
# 1055  At Belk, we have a vision to reimagine the dep...
# 705   Food Safety QA Technical Manager Princeton, N....
#
#                                            ground_truth  \
# 1501  RK K is hiring Transportation Engineers throug...
# 2586  Only Citizens GCs Preference for candidates lo...
# 2653  Ekeo Group is looking for a Senior Financial A...
# 1055  At Belk, we have a vision to reimagine the dep...
# 705   Food Safety QA Technical Manager Princeton, N....
#
#                                                  inputs
# 1501  RK K is hiring Transportation Engineers throug...
# 2586  Only Citizens GCs Preference for candidates lo...
# 2653  Ekeo Group is looking for a Senior Financial A...
# 1055  At Belk, we have a vision to reimagine the dep...
# 705   Food Safety QA Technical Manager Princeton, N....
#                                          predictions  \
# 0  As a Publix Pharmacy Associate, you ll see how...
# 1  Job Title Release Manager CLT Duration 12 18 m...
# 2  About This Role Wells Fargo is seeking a Senio...
# 3  We ve made a lot of progress since opening the...
# 4  At Whole Foods Market, we re committed to prov...
#
#                                         ground_truth  \
# 0  As a Publix Pharmacy Associate, you ll see how...
# 1  Job Title Release Manager CLT Duration 12 18 m...
# 2  About This Role Wells Fargo is seeking a Senio...
# 3  We ve made a lot of progress since opening the...
# 4  At Whole Foods Market, we re committed to prov...
#
#                                               inputs
# 0  As a Publix Pharmacy Associate, you ll see how...
# 1  Job Title Release Manager CLT Duration 12 18 m...
# 2  About This Role Wells Fargo is seeking a Senio...
# 3  We ve made a lot of progress since opening the...
# 4  At Whole Foods Market, we re committed to prov...

# %%
results = evaluate_dataset(small_gpt2_df)
# Out:
# 2025/05/10 02:04:38 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 100%|██████████| 1/1 [00:00<00:00,  1.17it/s]
# 100%|██████████| 1/1 [00:01<00:00,  1.03s/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.09it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.05it/s]
# 100%|██████████| 1/1 [00:01<00:00,  1.03s/it]
# 100%|██████████| 10/10 [00:01<00:00,  5.55it/s]
# 100%|██████████| 10/10 [00:01<00:00,  5.64it/s]
# 100%|██████████| 10/10 [00:02<00:00,  3.52it/s]
# 100%|██████████| 10/10 [00:01<00:00,  5.91it/s]
# 100%|██████████| 10/10 [00:01<00:00,  6.43it/s]
# 🏃 View run unruly-moose-537 at: http://localhost:5000/#/experiments/441364640883767191/runs/8a536d7e842e4a68927b6547acd7ad65
# 🧪 View experiment at: http://localhost:5000/#/experiments/441364640883767191
# {'grammar_quality/v1/mean': np.float64(1.6), 'grammar_quality/v1/variance': np.float64(0.24000000000000005), 'long_range_coherence_consistency/v1/mean': np.float64(2.5), 'long_range_coherence_consistency/v1/variance': np.float64(0.25), 'generation_novelty_non_repetitiveness/v1/mean': np.float64(1.6), 'generation_novelty_non_repetitiveness/v1/variance': np.float64(0.24000000000000005), 'semantic_richness_nuance/v1/mean': np.float64(2.4), 'semantic_richness_nuance/v1/variance': np.float64(0.44000000000000006), 'professionalism/v1/mean': np.float64(2.6), 'professionalism/v1/variance': np.float64(0.44000000000000006), 'rougeL/v1/mean': np.float64(0.22778382820194215), 'rougeL/v1/variance': np.float64(0.0014181787434329111), 'rougeL/v1/p90': np.float64(0.2808586379668751), 'bleu/v1/mean': np.float64(0.10883285268753481), 'bleu/v1/variance': np.float64(0.002838067952211968), 'bleu/v1/p90': np.float64(0.16484604529535982), 'flesch_kincaid_grade_level/v1/mean': np.float64(13.940000000000001), 'flesch_kincaid_grade_level/v1/variance': np.float64(7.820399999999999), 'flesch_kincaid_grade_level/v1/p90': np.float64(17.18)}
# Downloading artifacts: 100%|██████████| 1/1 [00:00<00:00, 221.37it/s]
# Downloading artifacts: 100%|██████████| 1/1 [00:00<00:00, 343.35it/s]
#                                               inputs  \
# 0  As a Publix Pharmacy Associate, you ll see how...
# 1  Job Title Release Manager CLT Duration 12 18 m...
# 2  About This Role Wells Fargo is seeking a Senio...
# 3  We ve made a lot of progress since opening the...
# 4  At Whole Foods Market, we re committed to prov...
# 5  PHD is a global communications planning and me...
# 6  Starting hiring pay range based on location, e...
# 7  Join a strong community where all we do is car...
# 8  Senior Data Science Lead Travel Analytics Loca...
# 9  Specialty Competency Assurance Industry Sector...
#
#                                         ground_truth  \
# 0  As a Publix Pharmacy Associate, you ll see how...
# 1  Job Title Release Manager CLT Duration 12 18 m...
# 2  About This Role Wells Fargo is seeking a Senio...
# 3  We ve made a lot of progress since opening the...
# 4  At Whole Foods Market, we re committed to prov...
# 5  PHD is a global communications planning and me...
# 6  Starting hiring pay range based on location, e...
# 7  Join a strong community where all we do is car...
# 8  Senior Data Science Lead Travel Analytics Loca...
# 9  Specialty Competency Assurance Industry Sector...
#
#                                          predictions  \
# 0  As a Publix Pharmacy Associate, you ll see how...
# 1  Job Title Release Manager CLT Duration 12 18 m...
# 2  About This Role Wells Fargo is seeking a Senio...
# 3  We ve made a lot of progress since opening the...
# 4  At Whole Foods Market, we re committed to prov...
# 5  PHD is a global communications planning and me...
# 6  Starting hiring pay range based on location, e...
# 7  Join a strong community where all we do is car...
# 8  Senior Data Science Lead Travel Analytics Loca...
# 9  Specialty Competency Assurance Industry Sector...
#
#    grammar_quality/v1/score  \
# 0                         1
# 1                         2
# 2                         2
# 3                         1
# 4                         2
# 5                         1
# 6                         2
# 7                         2
# 8                         1
# 9                         2
#
#                     grammar_quality/v1/justification  \
# 0  The output contains numerous grammar errors, i...
# 1  The output contains some grammar errors, such ...
# 2  The output contains some grammar errors and re...
# 3  The output contains numerous grammar errors, s...
# 4  The output contains some grammatical errors an...
# 5  The output contains numerous grammar errors, s...
# 6  The output contains several grammar errors, su...
# 7  The output contains some grammar errors, such ...
# 8  The output contains many grammar errors, such ...
# 9  The output contains some grammar errors, such ...
#
#    long_range_coherence_consistency/v1/score  \
# 0                                          2
# 1                                          3
# 2                                          3
# 3                                          2
# 4                                          2
# 5                                          2
# 6                                          2
# 7                                          3
# 8                                          3
# 9                                          3
#
#    long_range_coherence_consistency/v1/justification  \
# 0  The output contains some coherence issues, wit...
# 1  The output maintains a generally coherent them...
# 2  The output maintains a generally coherent them...
# 3  The output contains some coherence issues, wit...
# 4  The output contains some coherence issues, wit...
# 5  The output contains some coherence issues, wit...
# 6  The output contains some coherence issues, wit...
# 7  The output maintains a generally coherent them...
# 8  The output maintains a generally coherent them...
# 9  The output maintains a generally coherent them...
#
#    generation_novelty_non_repetitiveness/v1/score  \
# 0                                               1
# 1                                               2
# 2                                               2
# 3                                               2
# 4                                               1
# 5                                               1
# 6                                               2
# 7                                               2
# 8                                               1
# 9                                               2
#
#   generation_novelty_non_repetitiveness/v1/justification  \
# 0  The output is highly repetitive, with excessiv...
# 1  The output contains noticeable repetition of p...
# 2  The output contains noticeable repetition of p...
# 3  The output contains noticeable repetition of p...
# 4  The output is highly repetitive, with numerous...
# 5  The output is highly repetitive, with numerous...
# 6  The output contains noticeable repetition of p...
# 7  The output contains noticeable repetition of p...
# 8  The output is highly repetitive, with numerous...
# 9  The output contains noticeable repetition of p...
#
#    semantic_richness_nuance/v1/score  \
# 0                                  2
# 1                                  3
# 2                                  3
# 3                                  2
# 4                                  1
# 5                                  2
# 6                                  3
# 7                                  3
# 8                                  2
# 9                                  3
#
#            semantic_richness_nuance/v1/justification  \
# 0  The output uses limited vocabulary and is most...
# 1  The output uses adequate vocabulary and genera...
# 2  The output uses adequate vocabulary and genera...
# 3  The output uses limited vocabulary and is most...
# 4  The output is highly repetitive, using the sam...
# 5  The output uses limited vocabulary and is larg...
# 6  The output uses adequate vocabulary and genera...
# 7  The output uses adequate vocabulary and genera...
# 8  The output uses limited vocabulary and is most...
# 9  The output uses adequate vocabulary and convey...
#
#    professionalism/v1/score  \
# 0                         2
# 1                         3
# 2                         4
# 3                         2
# 4                         2
# 5                         2
# 6                         2
# 7                         3
# 8                         3
# 9                         3
#
#                     professionalism/v1/justification  rougeL/v1/score  \
# 0  The output is somewhat formal but contains exc...         0.216949
# 1  The output is formal and appropriate for busin...         0.296422
# 2  The output is highly professional, formal, and...         0.208791
# 3  The output is somewhat formal but contains rep...         0.165869
# 4  The output is somewhat repetitive and lacks cl...         0.228448
# 5  The output is somewhat formal but contains rep...         0.228517
# 6  The output is somewhat neutral but contains re...         0.218750
# 7  The output is formal and appropriate for busin...         0.250855
# 8  The output is formal and appropriate for busin...         0.279129
# 9  The output is formal and appropriate for busin...         0.184106
#
#    bleu/v1/score  flesch_kincaid_grade_level/v1/score
# 0       0.155538                                 17.9
# 1       0.173012                                 14.9
# 2       0.063668                                 17.1
# 3       0.028364                                 12.9
# 4       0.134299                                 10.2
# 5       0.125239                                 16.9
# 6       0.060346                                  9.7
# 7       0.163939                                 10.9
# 8       0.149800                                 14.3
# 9       0.034122                                 14.6
